# %% [markdown]
# ![image.png](attachment:ab066aea-d174-40c9-99f0-9c19d7590733.png)

# %%
a=[]
for i in l:
    if type(i)==int:
        a.append(i)
    elif type(i)==list:
        for j in i:
            if type(j)==int:
                a.append(j)
    elif type(i)==tuple:
        for k in i:
            if type(k)==int:
                a.append(k)
    elif type(i)==set:
        for q in i:
            if type(q)==int:
                a.append(q)
    elif type(i)==dict:
        for m in i.keys():
            if type(m)==int:
                a.append(m)
        for n in i.values():
            if type(n)==int:
                a.append(n)
            elif type(n)==list:
                for o in n:
                    a.append(o)
            elif type(n)==tuple:
                for p in n:
                    a.append(p)
    
a
from functools import reduce
reduce(lambda x,y : x*y , a)
# Out:
# 4134711838987085478833841242112000

# %% [markdown]
# ![image.png](attachment:8f90e997-21aa-4b0e-942c-245b0e1bc79d.png)

# %%
l = "I want to become a Data Scientist"
l_new = l.lower()
for i in l_new:
    ch = chr(219-ord(i))
    if (ch == chr(187)):
        print("$" , end='')
    else:
        print(ch , end='')
# Out:
# r$dzmg$gl$yvxlnv$z$wzgz$hxrvmgrhg
